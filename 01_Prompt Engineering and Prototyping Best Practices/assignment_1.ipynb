# %% [markdown]
# ### 🏗️ Activity #1:
# Please evaluate your system on the following questions:

# %% [markdown]
# 1. Explain the concept of object-oriented programming in simple terms to a complete beginner.
# Aspect Tested: zero-shot learning - running inference on llm
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Read the following paragraph and provide a concise summary of the key points…
# Aspect Tested: summarization capability of llm
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Write a short, imaginative story (100–150 words) about a robot finding friendship in an unexpected place.
# Aspect Tested: creativity of the llm and how well it follows the instructions (determined based on word count)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. If a store sells apples in packs of 4 and oranges in packs of 3, how many packs of each do I need to buy to get exactly 12 apples and 9 oranges?
# Aspect Tested: reasoning capability of llm - ability to reason through an arithmetic problem
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Rewrite the following paragraph in a professional, formal tone…
# Aspect Tested: Tone/persona" of the llm - ability to rewrite text in a professional tone
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🚧 Advanced Build:

# %% [markdown]
# Please make adjustments to your application that you believe will improve the vibe check done above, push the changes to your HF Space and redo the above vibe check.

# %% [markdown]
# 1. Explain the concept of object-oriented programming in simple terms to a complete beginner.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Read the following paragraph and provide a concise summary of the key points…
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Write a short, imaginative story (100–150 words) about a robot finding friendship in an unexpected place.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Rewrite the following paragraph in a professional, formal tone…
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🧑‍🤝‍🧑❓ Discussion Question #1:

# %% [markdown]
# What are some limitations of vibe checking as an evaluation tool?

# %% [markdown]
# vibe checking is a subjective evaluation of the llm's output. It is not a comprehensive evaluation, nor is it a standardized evaluation.
